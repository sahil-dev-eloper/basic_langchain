# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Capital of India")
response.content
# Out:
# 'The capital of India is **New Delhi**.'

# %%
from langchain.messages import SystemMessage, HumanMessage,AIMessage

messages=[
    SystemMessage("You are a poetic commentator"),
    HumanMessage("Describe Men's T20 Cricket World Cup 2024 win")
]

response=model.invoke(messages)
response.content
# Out:
# "The Caribbean breeze, a whispered plea,\nCarried a nation's destiny.\nThirteen long years, a burning thirst,\nFor cricket's crown, to be the first\nTo conquer all, in T20's fiery might,\nAnd banish shadows into light.\n\nFrom distant shores, the Men in Blue arrived,\nWith a dream rekindled, fiercely revived.\nThrough group stage battles, semi-final's fray,\nThey carved their path, come what may.\nTo Barbados' sun, the final stage was set,\nAgainst the Proteas, who'd known no conquest yet.\n\nThe tension crackled, in the humid air,\nAs Kohli's bat, dispelled despair.\nA maestro's innings, steady, true and deep,\nWhile boundaries flowed, and promises to keep.\nHe built the fortress, brick by careful run,\nBeneath the gaze of the setting sun.\n\nThen came the chase, a thrilling, desperate surge,\nAs Proteas' power, threatened to emerge.\nThe scoreboard raced, the hopes began to wane,\nA familiar heartbreak, threatened once again.\nWhen hope seemed lost, a flicker, then a flame,\nIgnited by a hero's sacred name.\n\nBumrah's precision, a surgical, deadly art,\nTore through the batting, ripped the chase apart.\nAnd Suryakumar, with a leap so grand,\nDefied gravity, a catch across the land.\nBut Hardik's over, the final, nervy test,\nWith steel in his gaze, he put the fears to rest.\n\nThe final ball, a roar that shook the skies,\nReflected glory in a billion eyes.\nThe cup was theirs! The long, long wait was done,\nA golden triumph, hard-earned, truly won.\nFrom Rohit's heart, to every tearful soul,\nThey'd played as one, and reached their ultimate goal.\n\nThe tricolour waved, a proud and vibrant sight,\nAs champions danced, in pure, unbridled light.\nThe Men in Blue, forever etched in fame,\nA T20 legend, whispered by their name.\nThe wait is over, the yearning finally ceased,\nA nation's joy, gloriously released."

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4

# %%
response.usage_metadata
# Out:
# {'input_tokens': 35,
#  'output_tokens': 33,
#  'total_tokens': 68,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 26}}
